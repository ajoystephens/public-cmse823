# %%
# LIBRARIES
import numpy as np

# %%
# Functions to define A and the appropriate b
def getA(n):
    A = np.ones([n,n])
    for i in range(n):
        for j in range(n):
            A[i,j]=1.00/((i+1)+(j+1)-1)
    return(A)

def getb(A):
    x = np.ones(A.shape[0])
    b = np.matmul(A,x)
    return(b)

# %% [markdown]
# The following functions calculate $G$ and $h$ so that:</br>
# $G = A^*A+\alpha^2I$</br>
# $h = A^* b$
#
# $$(A^*A+\alpha^2I) x_{Tik}=A^* b \text{ becomes } G x_{Tik} = h$$

# %%
def getG(A,alpha):
    n = A.shape[1]
    I = np.identity(n)
    
    G = np.matmul(A.T,A) + (alpha*I)
    return(G)

def geth(A):
    b = getb(A)
    h = np.matmul(A.T,b)
    return(h)

# %%
# FOLLOWING FUNCTION IS BORROWED FROM MY SUBMISSION FOR HW06
# implementation of modified Gram-Schmidt following Algorithm 8.1
def modifiedGS(matrix):
    n=matrix.shape[1]               # n = number of columns of matrix
    v=np.zeros(matrix.shape, float) # setup v as empty mxn
    q=np.zeros(matrix.shape, float) # setup q as empty mxn
    r=np.zeros((n,n), float)        # setup r as empty nxn
    
    for i in range(n):
        v[:,i]=matrix[:,i].copy()
    
    for i in range(n):
        r[i,i]=np.linalg.norm(v[:,i],2)
        q[:,i]=v[:,i]/r[i,i]
        for j in range(i,n):
            r[i,j]=np.dot(q[:,i],matrix[:,j])
            v[:,j]=v[:,j]-(r[i,j]*q[:,i])
    return(q,r)


# FOLLOWING FUNCTION IS BORROWED FROM MY SUBMISSION FOR HW09
# Backward Substitution Algorithm
def backwardSub(U,y):
    n = y.shape[0]
    x = np.ones(n) # construct basic y
    for i in range(n-1,-1,-1):
        # print('i',i)
        c=0
        for j in range(n-1,i,-1):
            # print(' j',j)
            c+=U[i,j]*x[j]
        x[i] = (y[i]-c)/U[i,i]
        # print(i)
    
    return(x)

# %%
# the followint is adapted from Algorithm 11.2 in the text
def leastSquares(G,h):
    # Compute QR factorization G=QR
    Q,R = modifiedGS(G)
    # Compute Q^* h
    Qb = np.matmul(Q.T,h)
    # Solve upper triangular system Rx = Q^* b
    x = backwardSub(R,Qb)
    return(x)

def avgDiffFromOne(x):
    ones = np.ones(x.shape)
    diff = np.abs(x-ones)
    return(np.mean(diff))

# %%
n = 10
alpha = 0.1

A = getA(n)
G = getG(A,alpha)
h = geth(A)
x = leastSquares(G,h)
x
# Out:
# array([1.26072737, 1.15824953, 1.01859839, 0.90318894, 0.81026587,
#        0.73456559, 0.6718745 , 0.61914283, 0.57417571, 0.5353707 ])

# %%
nValues = [10, 20, 30]
alphaValues = [0, 0.00000001, 0.00001, 0.001, 0.1]

for n in nValues:
    for alpha in alphaValues:
        print('n: '+str(n)+', alpha: '+str(alpha)+' --------------------------')
        A = getA(n)
        G = getG(A,alpha)
        h = geth(A)
        x = leastSquares(G,h)
        print(' x: '+str(x))
        print(' Average Difference from One: '+str(avgDiffFromOne(x)))
        print('---------------------------------------------------------------')
# Out:
# n: 10, alpha: 0 --------------------------
#  x: [ 0.88365503  2.74067467 -4.42077553  3.7394779   7.22265967 -3.51439843
#   0.41438715  0.15098225  0.06590039  2.69498001]
#  Average Difference from One: 2.481804139186681
# ---------------------------------------------------------------
# n: 10, alpha: 1e-08 --------------------------
#  x: [ 1.16590917 -0.87960929  4.74173162  1.13566857 -0.59035468 -0.06336052
#  -0.03132215 -0.01741625 -0.011496    4.74950241]
#  Average Difference from One: 1.538637066796284
# ---------------------------------------------------------------
# n: 10, alpha: 1e-05 --------------------------
#  x: [1.0075465  0.9599234  1.00270063 1.03028873 1.03770998 1.0305745
#  1.01412921 0.99210136 0.96693534 0.94022062]
#  Average Difference from One: 0.02637688334233479
# ---------------------------------------------------------------
# n: 10, alpha: 0.001 --------------------------
#  x: [0.9502925  1.06596801 1.09998645 1.08419621 1.0476129  1.0034118
#  0.95753396 0.91267627 0.87002224 0.83002578]
#  Average Difference from One: 0.07806246068793313
# ---------------------------------------------------------------
# n: 10, alpha: 0.1 --------------------------
#  x: [1.26072737 1.15824953 1.01859839 0.90318894 0.81026587 0.73456559
#  0.6718745  0.61914283 0.57417571 0.5353707 ]
#  Average Difference from One: 0.25889911417484884
# ---------------------------------------------------------------
# n: 20, alpha: 0 --------------------------
#  x: [ 1.70713909e-01  1.41342147e+01 -4.68008524e+01  5.72986536e+01
#  -1.44639768e+01  1.44396644e-01  2.31796479e-02  6.75176895e-03
#   2.85547923e-03  1.27261483e-03  6.71889060e-04  4.10693898e-04
#   2.54185873e-04  1.79779978e-04  1.26436005e-04  1.02057419e-04
#   6.51430147e-05  5.58820353e-05  3.80060939e-05  9.98883948e+00]
#  Average Difference from One: 7.8167731398004126
# ---------------------------------------------------------------
# n: 20, alpha: 1e-08 --------------------------
#  x: [ 3.94742588e-01  1.05559446e+01 -3.26729628e+01  3.69019481e+01
#  -4.60640217e+00  1.20976070e-01  1.25748783e-02  1.98484800e-03
#   1.05095205e-03  1.27899249e-04  7.83180124e-05  6.28942247e-05
#   2.96031992e-05 -1.27425146e-05 -5.53153854e-07 -3.06368122e-05
#  -2.61590584e-06 -1.61222854e-05 -1.31587945e-05  9.78850686e+00]
#  Average Difference from One: 5.399710617387488
# ---------------------------------------------------------------
# n: 20, alpha: 1e-05 --------------------------
#  x: [0.9999468  1.01780294 0.97325834 0.97080318 0.98466841 1.001343
#  1.01543869 1.0253844  1.03095557 1.03257253 1.03082783 1.02631607
#  1.01957338 1.01105542 1.00114485 0.9901864  0.97842166 0.96606621
#  0.95331095 0.94028255]
#  Average Difference from One: 0.022773508379720336
# ---------------------------------------------------------------
# n: 20, alpha: 0.001 --------------------------
#  x: [0.99810068 0.91616906 1.00205563 1.06049357 1.08965018 1.09873645
#  1.09490766 1.08290756 1.06581023 1.04561636 1.02364079 1.00075531
#  0.97754121 0.9543864  0.93154829 0.90919528 0.8874345  0.86633061
#  0.84591877 0.82621362]
#  Average Difference from One: 0.07258676536196489
# ---------------------------------------------------------------
# n: 20, alpha: 0.1 --------------------------
#  x: [1.11055212 1.27636584 1.22840343 1.15333093 1.07896025 1.01092502
